# %% [markdown]
# Neste notebook serão feitas a exploração dos dados, com exibição de gráficos relacionando as colunas e suas
# respectivas interpretações.

# %%
import matplotlib.pyplot as plt
import seaborn as sbn
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
pd_filmes = pd.read_json("filmes.json", )

# %%
pd_filmes.index = pd_filmes.index.order()

# %% [markdown]
# ### Filmes mais bem avaliados por ano pelo público

# %%
max_rating_per_year = pd_filmes.groupby(['year']).max()

# %%
max_rating_per_year[['pt_title','rating']]
# Out:
#                                       pt_title  rating
# year
# 1914                   A Embriaguez do Sucesso     8.2
# 1915                 O Nascimento de Uma Nação     6.9
# 1921                      O Médico e o Monstro     8.4
# 1922            Nosferatu - O Vampiro da Noite     8.0
# 1923                             O Homem Mosca     8.3
# 1924      Os Nibelungos - A Morte de Siegfried     8.0
# 1925                        Sete Oportunidades     8.0
# 1926          Torrente - O Braço Errado da Lei     8.3
# 1927     The Lodger: A Story of the London Fog     8.3
# 1928                             Vento e Areia     8.4
# 1929                       Melodia da Broadway     7.9
# 1930                                  Marrocos     8.0
# 1931                M, O Vampiro de Dusseldorf     8.6
# 1932                Zaroff, O Caçador de Vidas     8.2
# 1933                       Uma Loira para Três     8.1
# 1934                          Rainha Christina     8.3
# ...

# %%
mean_rating_per_year = pd_filmes.groupby(['year']).mean()

# %% [markdown]
# ### Avaliacão média dos filmes por ano dada pelo público (rating)

# %%
mean_rating_per_year[['rating']]
# Out:
#         rating
# year
# 1914  8.200000
# 1915  6.900000
# 1921  7.800000
# 1922  7.833333
# 1923  8.300000
# 1924  7.950000
# 1925  7.900000
# 1926  6.800000
# 1927  7.775000
# 1928  7.814286
# 1929  7.325000
# 1930  7.200000
# 1931  8.033333
# 1932  7.466667
# 1933  7.566667
# 1934  7.685714
# 1935  7.466667
# 1936  7.400000
# 1937  7.670000
# 1938  7.722222
# 1939  7.587500
# 1940  7.685714
# 1941  7.012500
# 1942  7.494737
# 1943  7.261538
# 1944  7.588235
# 1945  7.564286
# 1946  7.700000
# 1947  7.366667
# 1948  7.750000
# 1949  7.506667
# 1950  7.580952
# 1951  7.369231
# 1952  7.552381
# 1953  7.292857
# 1954  7.466667
# 1955  7.490000
# 1956  7.437931
# 1957  7.455000
# 1958  7.487500
# 1959  7.382353
# 1960  7.409091
# 1961  7.344444
# 1962  7.465000
# 1963  7.460870
# 1964  7.116129
# 1965  7.468750
# 1966  7.035294
# 1967  7.266667
# 1968  7.086207
# 1969  7.243478
# 1970  7.235294
# 1971  7.012500
# 1972  7.128889
# 1973  7.324324
# 1974  7.025000
# 1975  6.788372
# ...

# %% [markdown]
# ###### Observe que a nota dada foi descrescente ao longo dos anos

# %%
mean_rating_per_year[['rating']].plot(figsize=(20,10))

plt.xlim(1912, 2016)

plt.show()

# %% [markdown]
# ### Os filmes mais votados por ano

# %%
max_rating_per_year[['pt_title','votes']]
# Out:
#                                       pt_title   votes
# year
# 1914                   A Embriaguez do Sucesso   16893
# 1915                 O Nascimento de Uma Nação   14656
# 1921                      O Médico e o Monstro   47838
# 1922            Nosferatu - O Vampiro da Noite   59558
# 1923                             O Homem Mosca   10831
# 1924      Os Nibelungos - A Morte de Siegfried    3468
# 1925                        Sete Oportunidades   34407
# 1926          Torrente - O Braço Errado da Lei   10221
# 1927     The Lodger: A Story of the London Fog   89759
# 1928                             Vento e Areia   29421
# 1929                       Melodia da Broadway    6438
# 1930                                  Marrocos   31235
# 1931                M, O Vampiro de Dusseldorf   80934
# 1932                Zaroff, O Caçador de Vidas   28067
# 1933                       Uma Loira para Três   58689
# 1934                          Rainha Christina   51399
# ...

# %%
max_rating_per_year[['votes']].plot(figsize=(20,10))
plt.xlim(1912, 2016)
plt.show()

# %%
pd_filmes.plot(kind = 'scatter', x = 'year', y = 'rating', figsize=(20,10))

plt.xlim(1912, 2015)

plt.show()

# %% [markdown]
# ### Relação entre duração do filme e avaliação dada pelo público

# %%
pd_filmes.plot(kind = 'scatter', x = 'running_time', y = 'rating', figsize=(20,10))
plt.show()

# %% [markdown]
# Há poucos filmes com menos de 50 minutos ou com mais de 200 minutos de duração.  Do gráfico, também podemos notar que a avaliação dada aos filmes com mais de 200 minutos é, em geral, bem alta.

# %% [markdown]
# ### Relação entre a quantidade de votos e a avaliação dada pelo público

# %%
pd_filmes.plot(kind = 'scatter', x = 'votes', y = 'rating', figsize=(20,10))
xmin, xmax = plt.xlim()
plt.xlim(0, 140000)
plt.show()

# %% [markdown]
# ### Quantidade de filmes por ano

# %%
movies_per_year = pd_filmes.groupby('year').count()

# %%
plt.figure(figsize=(20,10))

movies_per_year.plot(kind='bar', y = 'pt_title')

plt.show()

# %% [markdown]
# ### Quantidade de filmes por avaliação

# %%
movies_rating = pd_filmes.groupby('rating').count()

plt.figure(figsize=(20,10))

movies_rating.plot(kind='bar', y = 'pt_title')

plt.show()

# %% [markdown]
# ### Quantidade de filmes por duração

# %%
movies_running = pd_filmes[pd_filmes.running_time>0].groupby('running_time').count()

plt.figure(figsize=(20,10))

movies_running.plot(kind='bar', y = 'pt_title')

plt.show()

# %% [markdown]
# ### Filmes mais longos

# %%
#pd_filmes[['pt_title' 'year', 'running_time', 'votes']].order()
pd_filmes[['pt_title', 'year', 'running_time', 'votes']].sort(('running_time'), ascending=False)
# Out:
#                                   pt_title  year  running_time   votes
# 9307                          Guerra e Paz  1966           427    4210
# 4464                    La meglio gioventù  2003           383   14386
# 3030                    Gangs of Wasseypur  2012           320   25764
# 4258                                  1900  1976           317   15562
# 8745                         Sàidékè balái  2012           276    4680
# 3603                      Anjos Assassinos  1993           271   20228
# 9082                 Dr. Mabuse, o Jogador  1922           242    4372
# 8528                              Napoleão  1927           240    4885
# 5084                    ...E o Vento Levou  1940           238  176094
# 7870                       Ai no mukidashi  2009           237    5504
# 5030                Era Uma Vez na América  1984           229  176614
# 7822   A Maior História de Todos os Tempos  1965           225    5548
# ...

# %%
pd_filmes.plot(kind = 'scatter', x = 'votes', y = 'running_time', figsize=(20,10))

plt.xlim(2000, 1400000)
plt.ylim(0,500)
plt.show()

# %% [markdown]
# ### Filmes mais bem avaliados

# %%
pd_filmes[['pt_title', 'year', 'rating', 'votes']].sort(('rating'), ascending=False)
# Out:
#                                                 pt_title  year  rating  \
# 628                                    O Poderoso Chefão  1972     9.2
# 3195                                O Poderoso Chefão II  1975     9.1
# 1097                                        Interestelar  2014     8.9
# 8405                O Senhor dos Anéis: O Retorno do Rei  2003     8.9
# 8804                                            Drishyam  2013     8.9
# 9532                                          Anbe Sivam  2003     8.9
# 4963                    Pulp Fiction: Tempo de Violência  1995     8.9
# 2086                                A Lista de Schindler  1993     8.9
# 6330                                     Ko to tamo peva  1980     8.9
# 5762                                    Saban Oglu Saban  1977     8.9
# 5768                              Hababam sinifi tatilde  1978     8.8
# 5907                                     Sono de Inverno  2014     8.8
# ...

# %% [markdown]
# ### Mais bem avaliados e mais votados

# %%
pd_filmes[['pt_title', 'year', 'rating', 'votes']].sort(('rating','votes'), ascending=False)
# Out:
#                                                 pt_title  year  rating  \
# 628                                    O Poderoso Chefão  1972     9.2
# 3195                                O Poderoso Chefão II  1975     9.1
# 4963                    Pulp Fiction: Tempo de Violência  1995     8.9
# 8405                O Senhor dos Anéis: O Retorno do Rei  2003     8.9
# 2086                                A Lista de Schindler  1993     8.9
# 1097                                        Interestelar  2014     8.9
# 5762                                    Saban Oglu Saban  1977     8.9
# 6330                                     Ko to tamo peva  1980     8.9
# 8804                                            Drishyam  2013     8.9
# 9532                                          Anbe Sivam  2003     8.9
# 1653                                            A Origem  2010     8.8
# 7197             O Senhor dos Anéis: A Sociedade do Anel  2002     8.8
# ...

# %% [markdown]
# ### Top 10 de filmes mal avaliados

# %%
pd_filmes[['pt_title', 'year', 'rating', 'votes']].sort(('rating'), ascending=True)[0:10]
# Out:
#                                pt_title  year  rating  votes
# 7570                   Saving Christmas  2014     1.5   6035
# 5628         Birdemic: Shock and Terror  2010     1.8   9719
# 1707                             Gunday  2014     1.8  50191
# 3307       Bebês Geniais 2: Super Bebês  2004     1.9  22823
# 1152  Super-Heróis: A Liga da Injustiça  2003     1.9  67399
# 5151      Dünyayi Kurtaran Adam'in oglu  2006     1.9  11336
# 2607             A Gostosa e a Gosmenta  2008     1.9  31300
# 8313           Emret Komutanim: Sah Mat  2007     1.9   5095
# 2771         Manos - As Mãos do Destino  2003     1.9  29172
# 8256                  Rebelião Espacial  1988     2.0   5142
#
# [10 rows x 4 columns]

# %% [markdown]
# ### Distribuição de filmes por categoria sobre avaliação

# %%
def get_title_by_genre(genre):
    titles = []
    for movie in pd_filmes.values:
        if genre in movie[4]:
            titles.append(movie[7])
    return titles

# %%
scifi = pd_filmes[pd_filmes.pt_title.isin(get_title_by_genre('Sci-Fi')) == True]
crime = pd_filmes[pd_filmes.pt_title.isin(get_title_by_genre('Crime')) == True]
romance = pd_filmes[pd_filmes.pt_title.isin(get_title_by_genre('Romance')) == True]
animation = pd_filmes[pd_filmes.pt_title.isin(get_title_by_genre('Animation')) == True]
music = pd_filmes[pd_filmes.pt_title.isin(get_title_by_genre('Music')) == True]
comedy = pd_filmes[pd_filmes.pt_title.isin(get_title_by_genre('Comedy')) == True]
war = pd_filmes[pd_filmes.pt_title.isin(get_title_by_genre('War')) == True]
horror = pd_filmes[pd_filmes.pt_title.isin(get_title_by_genre('Horror')) == True]
adult = pd_filmes[pd_filmes.pt_title.isin(get_title_by_genre('Adult')) == True]
news = pd_filmes[pd_filmes.pt_title.isin(get_title_by_genre('News')) == True]
thriller = pd_filmes[pd_filmes.pt_title.isin(get_title_by_genre('Thriller')) == True]
western = pd_filmes[pd_filmes.pt_title.isin(get_title_by_genre('Western')) == True]
mystery = pd_filmes[pd_filmes.pt_title.isin(get_title_by_genre('Mystery')) == True]
drama = pd_filmes[pd_filmes.pt_title.isin(get_title_by_genre('Drama')) == True]
action = pd_filmes[pd_filmes.pt_title.isin(get_title_by_genre('Action')) == True]
musical = pd_filmes[pd_filmes.pt_title.isin(get_title_by_genre('Musical')) == True]
history = pd_filmes[pd_filmes.pt_title.isin(get_title_by_genre('History')) == True]
family = pd_filmes[pd_filmes.pt_title.isin(get_title_by_genre('Family')) == True]
adventure = pd_filmes[pd_filmes.pt_title.isin(get_title_by_genre('Adventure')) == True]
fantasy = pd_filmes[pd_filmes.pt_title.isin(get_title_by_genre('Fantasy')) == True]
sport = pd_filmes[pd_filmes.pt_title.isin(get_title_by_genre('Sport')) == True]
biography = pd_filmes[pd_filmes.pt_title.isin(get_title_by_genre('Biography')) == True]

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1, figsize = (20,6))


scifi.groupby('rating').count().plot(kind = 'bar', ax = axes[0],  y = 'pt_title')
crime.groupby('rating').count().plot(kind = 'bar', ax = axes[1], y = 'pt_title')

axes[0].set_title('Sci-fi')
axes[1].set_title('Crime')

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1, figsize = (20,6))


romance.groupby('rating').count().plot(kind = 'bar', ax = axes[0], y = 'pt_title')
animation.groupby('rating').count().plot(kind = 'bar', ax = axes[1], y = 'pt_title')

axes[0].set_title('Romance')
axes[1].set_title('Animation')

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1, figsize = (20,6))

music.groupby('rating').count().plot(kind = 'bar', ax = axes[0], y = 'pt_title')
comedy.groupby('rating').count().plot(kind = 'bar', ax = axes[1], y = 'pt_title')

axes[0].set_title('Music')
axes[1].set_title('Comedy')

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1, figsize = (20,6))


war.groupby('rating').count().plot(kind = 'bar', ax = axes[0], y = 'pt_title')
horror.groupby('rating').count().plot(kind = 'bar', ax = axes[1], y = 'pt_title')

axes[0].set_title('War')
axes[1].set_title('Horror')

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1, figsize = (20,6))

western.groupby('rating').count().plot(kind = 'bar', ax = axes[0], y = 'pt_title')
mystery.groupby('rating').count().plot(kind = 'bar', ax = axes[1], y = 'pt_title')

axes[0].set_title('Western')
axes[1].set_title('Mystery')

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1, figsize = (20,6))


drama.groupby('rating').count().plot(kind = 'bar', ax = axes[0], y = 'pt_title')
action.groupby('rating').count().plot(kind = 'bar', ax = axes[1], y = 'pt_title')

axes[0].set_title('Drama')
axes[1].set_title('Action')

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1, figsize = (20,6))

musical.groupby('rating').count().plot(kind = 'bar', ax = axes[0], y = 'pt_title')
history.groupby('rating').count().plot(kind = 'bar', ax = axes[1], y = 'pt_title')

axes[0].set_title('Musical')
axes[1].set_title('History')

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1, figsize = (20,6))

family.groupby('rating').count().plot(kind = 'bar', ax = axes[0], y = 'pt_title')
adventure.groupby('rating').count().plot(kind = 'bar', ax = axes[1], y = 'pt_title')

axes[0].set_title('Family')
axes[1].set_title('Adventure')

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1, figsize = (20,6))

fantasy.groupby('rating').count().plot(kind = 'bar', ax = axes[0], y = 'pt_title')
sport.groupby('rating').count().plot(kind = 'bar', ax = axes[1], y = 'pt_title')

axes[0].set_title('Fantasy')
axes[1].set_title('Sport')

# %%
biography.groupby('rating').count().plot(kind = 'bar',  y = 'pt_title', figsize = (20,6))

plt.title('Biography')

# %% [markdown]
# ### Quantidade de filmes por categoria ao longo dos anos

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (20,10))


scifi.groupby('year').count().plot(kind = 'bar', ax = axes[0][0],  y = 'pt_title')
crime.groupby('year').count().plot(kind = 'bar', ax = axes[0][1], y = 'pt_title')
romance.groupby('year').count().plot(kind = 'bar', ax = axes[1,0], y = 'pt_title')
animation.groupby('year').count().plot(kind = 'bar', ax = axes[1,1], y = 'pt_title')


axes[0][0].set_title('Sci-fi')
axes[0][1].set_title('Crime')
axes[1,0].set_title('Romance')
axes[1,1].set_title('Animation')

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (20,10))

music.groupby('year').count().plot(kind = 'bar', ax = axes[0,0], y = 'pt_title')
comedy.groupby('year').count().plot(kind = 'bar', ax = axes[0,1], y = 'pt_title')
war.groupby('year').count().plot(kind = 'bar', ax = axes[1,0], y = 'pt_title')
horror.groupby('year').count().plot(kind = 'bar', ax = axes[1,1], y = 'pt_title')

axes[0,0].set_title('Music')
axes[0,1].set_title('Comedy')
axes[1,0].set_title('War')
axes[1,1].set_title('Horror')

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (20,10))

western.groupby('year').count().plot(kind = 'bar', ax = axes[0,0], y = 'pt_title')
mystery.groupby('year').count().plot(kind = 'bar', ax = axes[0,1], y = 'pt_title')
drama.groupby('year').count().plot(kind = 'bar', ax = axes[1,0], y = 'pt_title')
action.groupby('year').count().plot(kind = 'bar', ax = axes[1,1], y = 'pt_title')

axes[0,0].set_title('Western')
axes[0,1].set_title('Mystery')
axes[1,0].set_title('Drama')
axes[1,1].set_title('Action')

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (20,10))

musical.groupby('year').count().plot(kind = 'bar', ax = axes[0,0], y = 'pt_title')
history.groupby('year').count().plot(kind = 'bar', ax = axes[0,1], y = 'pt_title')
family.groupby('year').count().plot(kind = 'bar', ax = axes[1,0], y = 'pt_title')
adventure.groupby('year').count().plot(kind = 'bar', ax = axes[1,1], y = 'pt_title')

axes[0,0].set_title('Musical')
axes[0,1].set_title('History')
axes[1,0].set_title('Family')
axes[1,1].set_title('Adventure')

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1, figsize = (20,10))
fantasy.groupby('year').count().plot(kind = 'bar', ax = axes[0], y = 'pt_title')
sport.groupby('year').count().plot(kind = 'bar', ax = axes[1], y = 'pt_title')

axes[0].set_title('Fantasy')
axes[1].set_title('Sport')

# %%
biography.groupby('year').count().plot(kind = 'bar',  y = 'pt_title', figsize = (12,12))

plt.title('Biography')

# %% [markdown]
# ### Distribuição dos filmes de acordo com a duração

# %%
fig, axes = plt.subplots(nrows = 9, ncols = 2, figsize = (20,20))
scifi.groupby('running_time').count().plot(kind = 'bar', ax = axes[0,0],  y = 'pt_title')
crime.groupby('running_time').count().plot(kind = 'bar', ax = axes[0,1], y = 'pt_title')
romance.groupby('running_time').count().plot(kind = 'bar', ax = axes[1,0], y = 'pt_title')
animation.groupby('running_time').count().plot(kind = 'bar', ax = axes[1,1], y = 'pt_title')
music.groupby('running_time').count().plot(kind = 'bar', ax = axes[2,0], y = 'pt_title')
comedy.groupby('running_time').count().plot(kind = 'bar', ax = axes[2,1], y = 'pt_title')
war.groupby('running_time').count().plot(kind = 'bar', ax = axes[3,0], y = 'pt_title')
horror.groupby('running_time').count().plot(kind = 'bar', ax = axes[3,1], y = 'pt_title')
western.groupby('running_time').count().plot(kind = 'bar', ax = axes[4,0], y = 'pt_title')
mystery.groupby('running_time').count().plot(kind = 'bar', ax = axes[4,1], y = 'pt_title')
drama.groupby('running_time').count().plot(kind = 'bar', ax = axes[5,0], y = 'pt_title')
action.groupby('running_time').count().plot(kind = 'bar', ax = axes[5,1], y = 'pt_title')
musical.groupby('running_time').count().plot(kind = 'bar', ax = axes[6,0], y = 'pt_title')
history.groupby('running_time').count().plot(kind = 'bar', ax = axes[6,1], y = 'pt_title')
family.groupby('running_time').count().plot(kind = 'bar', ax = axes[7,0], y = 'pt_title')
adventure.groupby('running_time').count().plot(kind = 'bar', ax = axes[7,1], y = 'pt_title')
fantasy.groupby('running_time').count().plot(kind = 'bar', ax = axes[8,0], y = 'pt_title')
sport.groupby('running_time').count().plot(kind = 'bar', ax = axes[8,1], y = 'pt_title')

# %% [markdown]
# ### 50 melhores diretores de acordo com a avaliação média dos filmes produzidos por cada um deles

# %%
pd_director = pd_filmes.groupby('director').mean()
a = pd_director['rating'].copy()
a.sort(ascending = False)

# %%
a[0:50]
# Out:
# director
# Jeethu Joseph              8.900000
# Slobodan Sijan             8.900000
# Sundar C.                  8.900000
# Bilal Lashari              8.800000
# Nick Morris                8.800000
# Ertem Egilmez              8.700000
# Orhan Aksoy                8.700000
# Ramesh Sippy               8.600000
# Olivier Nakache            8.600000
# Pawan Kumar                8.600000
# Marwan Hamed               8.600000
# Emilis Velyvis             8.600000
# Vikas Bahl                 8.600000
# Shimit Amin                8.500000
# Dragan Bjelogrlic          8.500000
# Aamir Khan                 8.500000
# Aleksandr Seryj            8.500000
# Rajkumar Santoshi          8.450000
# Moustapha Akkad            8.450000
# Rakeysh Omprakash Mehra    8.450000
# Leonid Gayday              8.433333
# Guel Arraes                8.400000
# Sergiu Nicolaescu          8.400000
# Sergio Leone               8.400000
# K. Asif                    8.400000
# Lee Unkrich                8.400000
# ...

# %% [markdown]
# ### Diretores com a média de avaliação mais baixa

# %%
a.sort(ascending=True)
a[0:50]
# Out:
# director
# Darren Doane              1.50
# James Nguyen              1.80
# Taner Akvardar            1.90
# Tom Putnam                1.90
# Harold P. Warren          1.90
# Ulli Lommel               2.00
# William Heins             2.00
# David Winters             2.00
# Alberto De Martino        2.10
# Joel Silverman            2.20
# Ted V. Mikels             2.20
# Ray Dennis Steckler       2.20
# Rick Sloane               2.30
# Andrew Green              2.30
# Gábor Forgács             2.30
# Farhad Mann               2.30
# György Gát                2.30
# John Murlowski            2.30
# Sam Mraovich              2.30
# Roger Christian           2.40
# Michael Rae               2.40
# Kevin Elders              2.40
# Nicholas Webster          2.50
# Bill Couturié             2.50
# Bob Bralver               2.60
# Coleman Francis           2.60
# Saran Barnun              2.60
# Jacques Dorfmann          2.60
# Adam Bernstein            2.60
# ...

# %% [markdown]
# ### Diretores que mais dirigiram filmes

# %%
c_director = pd_filmes.groupby(['director'])

# %%
c_director.count().sort(('pt_title'), ascending = False).pt_title
# Out:
# director
# Woody Allen          40
# Alfred Hitchcock     38
# Clint Eastwood       30
# Steven Spielberg     27
# Steven Soderbergh    23
# Martin Scorsese      23
# Joel Schumacher      22
# Ridley Scott         22
# Sidney Lumet         21
# Brian De Palma       21
# Ron Howard           19
# William Wyler        19
# David Cronenberg     18
# Walter Hill          18
# John Huston          18
# ...
# Liz W. Garcia           1
# Liz Friedlander         1
# Lisa Gottlieb           1
# Lisa Azuelos            1
# Linda Mendoza           1
# Lili Fini Zanuck        1
# Liev Schreiber          1
# Liam Lynch              1
# Li Zhang                1
# Lewis John Carlino      1
# Levent Semerci          1
# Levan Bakhia            1
# Leslye Headland         1
# Leslie H. Martinson     1
# A. Edward Sutherland    1
# Name: pt_title, Length: 3625, dtype: int64

# %% [markdown]
# Da tabela acima, podemos ver que Woody Allen foi quem dirigiu mais filmes.

# %% [markdown]
# ### Análise dos atores que foram estrelas nos filmes

# %%
print pd_filmes.stars
# Out:
# 2                [Tom Hanks, Robin Wright, Gary Sinise]
# 3         [Daniel Radcliffe, Emma Watson, Rupert Grint]
# 5                  [Bruce Willis, Mos Def, David Morse]
# 7     [Candice Bergen, Peter Strauss, Donald Pleasence]
# 8     [Otto Kruger, Gloria Holden, Marguerite Church...
# 9            [Bin Shimada, Masako Nozawa, Ryô Horikawa]
# 10            [David Jason, Amanda Root, Angela Thorne]
# 11          [Michael Crawford, Ben Vereen, Ellen Blain]
# 13                   [A.J. Cook, Ali Larter, Tony Todd]
# 14         [Alan Arkin, Pedro Cardoso, Fernanda Torres]
# 15       [Jim Broadbent, Colin Firth, Juliet Stevenson]
# 16       [Jimi Mistry, Kris Holden-Ried, Suleka Mathew]
# 17            [William Powell, Myrna Loy, Barry Nelson]
# 18    [Coralie Revel, Sabrina Seyvecou, Roger Miremont]
# 19             [Mark Harmon, Jodie Foster, Blair Brown]
# ...
# 10654    [Giancarlo Giannini, Mariangela Melato, Riccar...
# 10655         [Sylvia Sidney, Henry Fonda, Barton MacLane]
# ...

# %% [markdown]
# Dicionário relacionando ator(chave) a todos os filmes em que ele atuou (lista)

# %%
actors = {}
for item in pd_filmes.values:
    for actor in item[10]:
        if actor not in actors.keys():
            actors[actor] =  []
            actors[actor].append(item[7])
        else:
            actors[actor].append(item[7])

# %%
print actors['Tim Robbins']
# Out:
# [u'Alucina\xe7\xf5es do Passado', u'O Suspeito da Rua Arlington', u'Na Roda da Fortuna', u'Miss\xe3o: Marte', u'Sobre Meninos e Lobos', u'Guerra dos Mundos', u'O Jogador', u'Nada a Perder', u'Sorte no Amor', u'Short Cuts - Cenas da Vida', u'Howard, o Super-Her\xf3i', u'Amea\xe7a Virtual', u'A Teoria do Amor', u'C\xf3digo 46', u'Natureza Quase Humana', u'Terapia do Sexo', u'Top Gun: Ases Indom\xe1veis', u'Gente de Sorte', u'As Aventuras de Erik, o Viking', u'Um Conquistador em Apuros', u'A Vida Secreta das Palavras', u'Em Nome da Honra', u'O Segredo de Charlie', u'Passando dos Limites']

# %%
print len(actors)
# Out:
# 9835

# %% [markdown]
# há 9883 atores envolvidos nos filmes analisados

# %% [markdown]
# #### Atores que atuaram em mais filmes

# %%
values = []
for actor in actors.keys():
    pair = (actor.encode('utf-8'), len(actors[actor]))
    values.append(pair)
dtype = [('name', 'S30'), ('Qt_movies', int)]

mv = np.array(values, dtype = dtype)

# %%
famous_actors = np.sort(mv, order='Qt_movies', kind = 'mergesort')

# %%
for pair in famous_actors[::-1]:
    print pair[0], '=>', pair[1]
# Out:
# Robert De Niro => 63
# Nicolas Cage => 50
# Bruce Willis => 49
# Samuel L. Jackson => 48
# Dennis Quaid => 43
# Michael Caine => 42
# Jackie Chan => 42
# John Cusack => 41
# Sean Connery => 40
# Gene Hackman => 40
# Anthony Hopkins => 40
# Morgan Freeman => 39
# Clint Eastwood => 39
# Tom Hanks => 38
# Sylvester Stallone => 38
# Robin Williams => 38
# Liam Neeson => 36
# Ewan McGregor => 36
# Denzel Washington => 36
# Johnny Depp => 35
# John Travolta => 35
# Jean-Claude Van Damme => 35
# Harrison Ford => 35
# Julianne Moore => 34
# Eddie Murphy => 34
# Willem Dafoe => 33
# Susan Sarandon => 33
# Richard Gere => 33
# Julia Roberts => 33
# John Wayne => 33
# Jeff Bridges => 33
# Al Pacino => 33
# Shah Rukh Khan => 32
# Nicole Kidman => 32
# Meryl Streep => 32
# Matt Damon => 32
# Donald Sutherland => 32
# Christopher Walken => 32
# Antonio Banderas => 32
# Tommy Lee Jones => 31
# Tom Cruise => 31
# Steve Martin => 31
# Mel Gibson => 31
# John Goodman => 31
# Cameron Diaz => 31
# ...
